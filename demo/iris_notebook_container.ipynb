# %% [markdown]
# ### Run and connect to a containerized IRIS instance on a notebook

# %%
# !docker pull containers.intersystems.com/intersystems/iris-community:2024.1
# !docker pull intersystemsdc/iris-community:2024.1
# Out:
# Error response from daemon: failed to resolve reference "docker.io/intersystemsdc/iris-community:2024.1": docker.io/intersystemsdc/iris-community:2024.1: not found

# %%
from testcontainers.iris import IRISContainer
import os

image = 'intersystemsdc/iris-community:2024.1'
container = IRISContainer(image, username="demo", password="demo", namespace="demo")
container.with_exposed_ports(1972, 52773)
container.start()
CONNECTION_STRING = container.get_connection_url(os.getenv("IRIS_HOSTNAME","localhost"))
# Out:
# Pulling image testcontainers/ryuk:0.8.1
# Container started: 26997d2fc79a
# Waiting for container <Container: 26997d2fc79a> with image testcontainers/ryuk:0.8.1 to be ready ...
# Pulling image intersystemsdc/iris-community:2024.1
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/api/client.py:275, in APIClient._raise_for_status(self, response)
#     274 try:
# --> 275     response.raise_for_status()
#     276 except requests.exceptions.HTTPError as e:
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: http+docker://localhost/v1.47/containers/create
#
# The above exception was the direct cause of the following exception:
#
# ImageNotFound                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/models/containers.py:876, in ContainerCollection.run(self, image, command, stdout, stderr, remove, **kwargs)
#     875 try:
# --> 876     container = self.create(image=image, command=command,
#     877                             detach=detach, **kwargs)
#     878 except ImageNotFound:
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/models/containers.py:935, in ContainerCollection.create(self, image, command, **kwargs)
#     934 create_kwargs = _create_container_args(kwargs)
# --> 935 resp = self.client.api.create_container(**create_kwargs)
#     936 return self.get(resp['Id'])
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/api/container.py:440, in ContainerApiMixin.create_container(self, image, command, hostname, user, detach, stdin_open, tty, ports, environment, volumes, network_disabled, name, entrypoint, working_dir, domainname, host_config, mac_address, labels, stop_signal, networking_config, healthcheck, stop_timeout, runtime, use_config_proxy, platform)
#     432 config = self.create_container_config(
#     433     image, command, hostname, user, detach, stdin_open, tty,
#     434     ports, environment, volumes,
#    (...)
#     438     stop_timeout, runtime
#     439 )
# --> 440 return self.create_container_from_config(config, name, platform)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/api/container.py:457, in ContainerApiMixin.create_container_from_config(self, config, name, platform)
#     456 res = self._post_json(u, data=config, params=params)
# --> 457 return self._result(res, True)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/api/client.py:281, in APIClient._result(self, response, json, binary)
#     280 assert not (json and binary)
# --> 281 self._raise_for_status(response)
#     283 if json:
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/api/client.py:277, in APIClient._raise_for_status(self, response)
#     276 except requests.exceptions.HTTPError as e:
# --> 277     raise create_api_error_from_http_exception(e) from e
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/errors.py:39, in create_api_error_from_http_exception(e)
#      38         cls = NotFound
# ---> 39 raise cls(e, response=response, explanation=explanation) from e
#
# ImageNotFound: 404 Client Error for http+docker://localhost/v1.47/containers/create: Not Found ("No such image: intersystemsdc/iris-community:2024.1")
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/api/client.py:275, in APIClient._raise_for_status(self, response)
#     274 try:
# --> 275     response.raise_for_status()
#     276 except requests.exceptions.HTTPError as e:
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: http+docker://localhost/v1.47/images/create?tag=2024.1&fromImage=intersystemsdc%2Firis-community
#
# The above exception was the direct cause of the following exception:
#
# NotFound                                  Traceback (most recent call last)
# Cell In[1], line 7
#       5 container = IRISContainer(image, username="demo", password="demo", namespace="demo")
#       6 container.with_exposed_ports(1972, 52773)
# ----> 7 container.start()
#       8 CONNECTION_STRING = container.get_connection_url(os.getenv("IRIS_HOSTNAME","localhost"))
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/testcontainers/core/generic.py:74, in DbContainer.start(self)
#      72 def start(self) -> "DbContainer":
#      73     self._configure()
# ---> 74     super().start()
#      75     self._transfer_seed()
#      76     self._connect()
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/testcontainers/core/container.py:113, in DockerContainer.start(self)
#     100 self._configure()
#     102 network_kwargs = (
#     103     {
#     104         "network": self._network.name,
#    (...)
#     110     else {}
#     111 )
# --> 113 self._container = docker_client.run(
#     114     self.image,
#     115     command=self._command,
#     116     detach=True,
#     117     environment=self.env,
#     118     ports=self.ports,
#     119     name=self._name,
#     120     volumes=self.volumes,
#     121     **network_kwargs,
#     122     **self._kwargs,
#     123 )
#     125 logger.info("Container started: %s", self._container.short_id)
#     126 return self
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/testcontainers/core/docker_client.py:44, in _wrapped_container_collection.<locals>.wrapper(*args, **kwargs)
#      42 @ft.wraps(ContainerCollection.run)
#      43 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> _T:
# ---> 44     return function(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/testcontainers/core/docker_client.py:100, in DockerClient.run(self, image, command, environment, ports, labels, detach, stdout, stderr, remove, **kwargs)
#      98     if host_network:
#      99         kwargs["network"] = host_network
# --> 100 container = self.client.containers.run(
#     101     image,
#     102     command=command,
#     103     stdout=stdout,
#     104     stderr=stderr,
#     105     remove=remove,
#     106     detach=detach,
#     107     environment=environment,
#     108     ports=ports,
#     109     labels=create_labels(image, labels),
#     110     **kwargs,
#     111 )
#     112 return container
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/models/containers.py:879, in ContainerCollection.run(self, image, command, stdout, stderr, remove, **kwargs)
#     876     container = self.create(image=image, command=command,
#     877                             detach=detach, **kwargs)
#     878 except ImageNotFound:
# --> 879     self.client.images.pull(image, platform=platform)
#     880     container = self.create(image=image, command=command,
#     881                             detach=detach, **kwargs)
#     883 container.start()
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/models/images.py:464, in ImageCollection.pull(self, repository, tag, all_tags, **kwargs)
#     457     warnings.warn(
#     458         '`stream` is not a valid parameter for this method'
#     459         ' and will be overridden',
#     460         stacklevel=1,
#     461     )
#     462     del kwargs['stream']
# --> 464 pull_log = self.client.api.pull(
#     465     repository, tag=tag, stream=True, all_tags=all_tags, **kwargs
#     466 )
#     467 for _ in pull_log:
#     468     # We don't do anything with the logs, but we need
#     469     # to keep the connection alive and wait for the image
#     470     # to be pulled.
#     471     pass
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/api/image.py:429, in ImageApiMixin.pull(self, repository, tag, stream, auth_config, decode, platform, all_tags)
#     422     params['platform'] = platform
#     424 response = self._post(
#     425     self._url('/images/create'), params=params, headers=headers,
#     426     stream=stream, timeout=None
#     427 )
# --> 429 self._raise_for_status(response)
#     431 if stream:
#     432     return self._stream_helper(response, decode=decode)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/api/client.py:277, in APIClient._raise_for_status(self, response)
#     275     response.raise_for_status()
#     276 except requests.exceptions.HTTPError as e:
# --> 277     raise create_api_error_from_http_exception(e) from e
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/docker/errors.py:39, in create_api_error_from_http_exception(e)
#      37     else:
#      38         cls = NotFound
# ---> 39 raise cls(e, response=response, explanation=explanation) from e
#
# NotFound: 404 Client Error for http+docker://localhost/v1.47/images/create?tag=2024.1&fromImage=intersystemsdc%2Firis-community: Not Found ("failed to resolve reference "docker.io/intersystemsdc/iris-community:2024.1": docker.io/intersystemsdc/iris-community:2024.1: not found")

# %%
print(CONNECTION_STRING)

# %% [markdown]
# #### Using this connection string, you can connect and use IRIS as a vectordb via sql, langchain and llama_index as shown in the other demos.
